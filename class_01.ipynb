# %% [markdown]
# <a href="https://colab.research.google.com/github/imochasingh/colab/blob/main/class_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [1,3,4]
print(3 in a)
# Out:
# True
